# %%
from PIL import Image
import numpy as np
import math
import matplotlib.pyplot as plt
import random

# %%
im = Image.open("dataset/images/test/3096.jpg")
im.show()
im = np.asarray(im)
im.shape
# Out:
# (321, 481, 3)

# %%
def calculate_sd(x, y):
    mean = 0
    count = 0
    for i in range(x-1, x+2):
        for j in range(y-1, y+2):
            if(i >= 0 and i < im.shape[0] and j >= 0 and j < im.shape[1] and i is not x and j is not y):
                mean += im[i, j, 0] + im[i, j, 1] + im[i, j, 2]
                count += 1
    mean = mean/count
    #print(mean)
    
    sd = 0
    count = 0
    for i in range(x-1, x+2):
        for j in range(y-1, y+2):
            if(i >= 0 and i < im.shape[0] and j >= 0 and j < im.shape[1] and not (i is x and j is y)):
                sd += (im[i, j, 0] + im[i, j, 1] + im[i, j, 2] - mean)**2
                #print(i)
                #print(j)
                count += 1
             
    #print(sd)
    sd = math.sqrt(sd/count)
    
    return sd

# %%
def KMeans(n):
    means = random.sample(range(0, data.shape[0]), n)
    _ = 0
    epsilon = 1000
    
    while(_ < 10 and epsilon < 0.5):
        for i in range(data.shape[0]):
            min_dist = 1000000
            min_index = 1000000
            for j in range(len(means)):
                dist = np.linalg.norm(data[i]-data[means[j]])
                
                if dist < min_dist:
                    min_dist = dist
                    min_index = j

# %%
data = []
for i in range(im.shape[0]):
    for j in range(im.shape[1]):
        _ = im[i, j, :].tolist()
        _.append(i)
        _.append(j)
        _.append(calculate_sd(i, j))
        data.append(_)
# Out:
# /home/achilles/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning: overflow encountered in ubyte_scalars
#   import sys
# /home/achilles/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:17: RuntimeWarning: overflow encountered in ubyte_scalars

# %%
random.shuffle(data)
data = np.asarray(data)

# %%
data.shape
# Out:
# (154401, 6)

# %%
kmeans = KMeans(n_clusters=8, random_state=0).fit_predict(data)

# %%
a = random.sample(range(0, data.shape[0]), 8)

# %%
a
# Out:
# [142799, 63169, 43834, 101930, 98582, 27495, 17917, 121111]

# %%
plt.imshow(ans)

# %%
ans.shape
# Out:
# (321, 481)

# %%
plt.imshow(im)
